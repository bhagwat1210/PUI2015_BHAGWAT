# %%
#from __future__ import print_function
import numpy as np
__author__= 'bhagwat'
import os
from scipy.optimize import curve_fit, minimize
distributions = ['chisq']
mymean=100
df=100

# %%
mysize=2000/(np.array(range(1,100)+[10]))

# %%
md['chi']={} 
md['no']={}
md['bi']={}
md['po']={}
#and do it in a for loop. not pythonic, sigh..

for n in mysize:
    md['chi'][n] = np.random.chisquare(df, size=n)
    md['no'][n] =  np.random.normal(100,50,size=n)
    md['bi'][n] =  np.random.binomial(1000,.1, size=n)
    md['po'][n] =  np.random.poisson(100, size=n)
'for chisquare distributio'    
    
means = {}
means['chi'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['chi'].iterkeys():
    means['chi'][nn] = md['chi'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['chi'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)] ,[df,df], 'k')

# %%
'normal distribution'    
    
means = {}
means['no'] = {}

fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['no'].iterkeys():
    means['no'][nn] = md['no'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['no'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)] ,[df,df], 'k')

# %%
#'binomial distribution'

means = {}
means['bi'] = {}

fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['bi'].iterkeys():
    means['bi'][nn] = md['bi'][nn].mean()
    
     #and plot it
    axchisq_mu_n.plot(nn, means['bi'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)] ,[df,df], 'k')

# %%
#poisson distribution     
means = {}
means['po'] = {}

fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['po'].iterkeys():
        means['po'][nn] = md['po'][nn].mean()
        axchisq_mu_n.plot(nn, means['po'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size')
        axchisq_mu_n.set_ylabel('sample mean')
        axchisq_mu_n.plot([min(mysize), max(mysize)] ,[df,df], 'k')

# %%
'for exponential function'
md['exp']={} 

for n in mysize:
    md['exp'][n] = np.random.exponential(100, size=n)
    
means['exp'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['exp'].iterkeys():
    means['exp'][nn] = md['exp'][nn].mean()
    axchisq_mu_n.plot(nn, means['exp'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means:
    for m in means[n]:
        allmeans.append(means[n][m])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')
